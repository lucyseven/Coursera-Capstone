# %% [markdown]
# #  Project Name: Battle between New York, San Francisco and Seattle
# ## Which one is happier?

# %% [markdown]
# ###  Introduction and Business Problem
#
# In this project, I want to compare three big cities and their neighborhoods. City are the future of human beings. It exists for its convenient and the variebility it brings into every people's life.
#
# But also, stress comes along.
#
# Traffic, housing, different communities.
#
# New York, San Francisco and Seattle. They are all international modern cities. Which one is more suitable for living in terms of happiness?
#
# Other than venue data, I also want to compare population data and housing data.
#
# The study will answer many questions:
#
# Which one has the most population?
#
# What is the structure of the population in each city?
#
# Which one has the affordable house?
#
# How similar are these three cities?
#
# Is New York more like San Francisco or Seattle?
#
# Or is New York totally different to these two cities in the west coast?
#
# And how similarity is San Francisco and Seattle, for being two big cities on the west coast?

# %% [markdown]
# ###  Data
#
# 1. foursquare venue data
# Like the assignment I did in week 3, I will segmenting and clustering these three big cities based on the venue.
# Extract the top 5 venues in each cities.
#
# 2. Census data
# I am interested in population and race, and I can find the data from the united states census bureau.
# https://www.census.gov/data.html
#
# 3. housing
# https://www.data.gov/
#
#
# After I visulize the dataset, I plan to select a few elements to be the factors to determine the happiness of living in that city.
#
# By weighting them and combine them.
#
# In this end, I want to get a happiness index to rank these three cities.
